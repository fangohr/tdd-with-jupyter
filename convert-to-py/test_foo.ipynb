# %%
import foo

# %%
def test_sum():
    assert foo.sum(1, 2) == 3
    assert foo.sum("cat", "dog") == "catdog"

# %%
def test_prod():
    assert foo.prod(2, 4) == 8
    assert foo.prod(2, "cat") == "catcat"
